# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import seaborn as sb

# %% [markdown]
# # Performing EDA and Plots
# The goal of this notebook is to go through various datasets and explore useful plots to showcase data and how we can interpret plots for later use in ML infrastructure.

# %%
plt.style.use('ggplot')

# %% [markdown]
# # Reading in the mtcars Dataset

# %%
df = pd.read_csv('Data/mtcars.csv')

# %%
#plotting the MPG as a function of Horsepower
fig, ax = plt.subplots(figsize = (12, 6))
ax.scatter(df['hp'], df['mpg'], c = df['cyl'], s = 100)

# %% [markdown]
# # Reading in the economic Dataset

# %%
# Reading in the economics data
econ_df = pd.read_csv('Data/economics.csv', index_col = 0)

# %%
fig, ax = plt.subplots(figsize = (12, 6))
econ_df.plot(x = 'date', y = 'pce', secondary_y = True, ax = ax)
econ_df.plot(x = 'date', y = 'unemploy', secondary_y = True, ax = ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize = (12, 6))
econ_df.plot(x = 'date', y = 'psavert', secondary_y = True, ax = ax)
econ_df.plot(x = 'date', y = 'unemploy', secondary_y = True, ax = ax)
# Out:
# <Axes: >

# %% [markdown]
# # Reading in the AirPassenger Dataset

# %%
# Reading in the AirPassenger data
data = pd.read_csv('Data/AirPassengers.csv')

# %%
sb.histplot(data['#Passengers'], kde = True, bins = 20, color = 'purple')
# Out:
# <Axes: xlabel='#Passengers', ylabel='Count'>

# %% [markdown]
# # Reading in the Airquality Dataset

# %%
#Reading in the Air quality Data Set
air_data = pd.read_csv('Data/airquality.csv', index_col = 0)

# %%
fig, ax = plt.subplots(figsize = (12, 6), constrained_layout = True)
sb.violinplot(air_data, x = 'Month', y = 'Ozone', ax = ax, hue = 'Month')
#ax.grid(visible = True)
plt.show()

# %% [markdown]
# # Reading in the agriculture worldbanks Dataset

# %%
data = pd.read_csv('Data/agriculture_worldbank.csv')

# %%
GDP = data.iloc[:, 1:]
contry = data.iloc[:, 0]
years  = data.columns[1:]

# %%
plt.figure(figsize = (15, 7))
for gdp, country in zip(GDP.values, contry):
    plt.plot(years, gdp, label = country)

plt.xlabel('Years')
plt.ylabel('GDP')
plt.xticks(rotation=45)

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12, 6))
data.iloc[1, 1:].plot(kind = 'bar', figsize = (12, 6), color = 'purple', ax = ax)
ax.set_ylabel('GDP Brazil')
# Out:
# Text(0, 0.5, 'GDP Brazil')

# %%
fig, ax = plt.subplots(figsize = (12, 6))
sb.histplot(y = GDP.loc[1], kde = True, bins = 20, color = 'purple', ax = ax)
#.plot(kind = 'bar', figsize = (12, 6), color = 'purple', ax = ax, density = True)
ax.set_ylabel('GDP Brazil')
# Out:
# Text(0, 0.5, 'GDP Brazil')

# %%
fig, ax = plt.subplots(figsize = (12, 6))
sb.violinplot(data.T[1:], ax = ax)
ax.set_xticklabels(contry, rotation = 90)
ax.set_ylabel('GDP')
# Out:
# /var/folders/t2/6968g8md2c9g1mm1h0p9nxl588s4s1/T/ipykernel_53176/3765546806.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(contry, rotation = 90)
# Text(0, 0.5, 'GDP')
